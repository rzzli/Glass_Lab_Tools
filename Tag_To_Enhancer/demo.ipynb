# %%
# %%bash
#
# script=/home/zhl022/daima/to_share/Glass_Lab_Tools/Tag_To_Enhancer/tag_enhancer.sh
# myArray=("ctl" "il4" "lps"  )
# #myArray=( "lps"  )
# for condition in ${myArray[@]}; do
#     atac=$(ls -d /home/zhl022/daima/projects/make_peaks_Aug30/il4/tags/atac/${condition}/*)
#     chip=$(ls -d /home/zhl022/daima/projects/make_peaks_Aug30/il4/tags/chip/${condition}/*)
#     exp_name=${condition}
#     outd=/home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/${condition}
#     echo $outd
#     $script "${atac}" "${chip}" $exp_name mm10 $outd
# done
# Out:
# /home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl
# rickli
# /home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl
# C57Bl6_F_BMDM_ATAC_notx_rep1_MAH_l20180703
# C57Bl6_F_BMDM_ATAC_notx_rep2_MAH_l20180703
# Performing IDR analysis on the following samples: /home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl/C57Bl6_F_BMDM_ATAC_notx_rep1_MAH_l20180703_tag_atac_peaks.txt, /home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl/C57Bl6_F_BMDM_ATAC_notx_rep2_MAH_l20180703_tag_atac_peaks.txt
# Output files will be written to: /home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl/idr/
# Using the following IDR threshold: 0.05
# Peaks will be ranked using: findPeaks Score
# ['/home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl/C57Bl6_F_BMDM_ATAC_notx_rep1_MAH_l20180703_tag_atac_peaks.txt', '/home/zhl022/daima/projects/make_peaks_Aug30/il4/enhancers/ctl/C57Bl6_F_BMDM_ATAC_notx_rep2_MAH_l20180703_tag_atac_peaks.txt']
# ...
